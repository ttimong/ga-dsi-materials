# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# ## Guided Practice: Explore Python Data Viz
#
# _Author: Alexander Combs (NYC) Dave Yerrington (SF)_
#
# ---
#
# In this guided practice lab you will use Pandas, Matplotlib, and Seaborn to create simple plots.
#
# We'll cover plotting line plots, scatter plots, bar plots, histograms, and how to manipulate the style of your plots with Matplotlib.
#
# We will use primarily the Boston Housing data from the UCI repository.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %% [markdown]
# ### Pandas plotting documentation
#
# [Link to Documentation](http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.plot.html)

# %% [markdown]
# ### Create fake data for examples

# %%
df = pd.DataFrame(np.random.randn(10, 4), 
                  columns=['col1', 'col2', 'col3', 'col4'],
                  index=['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'])

# %% [markdown]
# ### Load in Boston housing data for exercises
#
# The data dictionary can be found [here](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/housing.names)

# %%
housing_csv = '../assets/datasets/boston_housing_data.csv'
housing = pd.read_csv(housing_csv)

# %% [markdown]
# ## Line plots
# ---

# %% [markdown]
# ### Line plot with a DataFrame

# %%
df.plot()

# %% [markdown]
# ### Line plot with a Series

# %%
df['col1'].plot()

# %% [markdown]
# ### Change the size of a plot

# %%
df.plot(figsize=(15,8)) # width, height

# %% [markdown]
# ### Change the color of a plot

# %%
df['col1'].plot(color='crimson', figsize=(16,8))

# %% [markdown]
# ### Change the style of individual lines

# %%
df[['col1', 'col4']].plot(figsize=(15,7), style={'col1': ':r', 'col4': 'vb'})

# %% [markdown]
# ### Create a line plot of ZN and INDUS in the housing data. For ZN use a solid green line and for INDUS use a blue dashed line.
#
# - Set the width to 12 and the height to 8.
# - Change the style sheet to something you find here [Style Sheets](https://tonysyu.github.io/raw_content/matplotlib-style-gallery/gallery.html)

# %%
housing[['ZN', 'INDUS']].plot(figsize=(12,8), style={'ZN': 'g', 'INDUS':'--b'})

# %% [markdown]
# ## Bar Plots
# ---

# %% [markdown]
# ### Bar plot from a series

# %%
df['col4'].plot(kind='bar', figsize=(16,8), fontsize=14)

# %% [markdown]
# ### Using a DataFrame and Matplotlib commands we can get fancy

# %%
ax = df.plot(kind='bar', figsize=(15,3))

# set the title
ax.set_title('Some Kinda Plot Thingy', fontsize=21, y=1.01)

# move the legend
ax.legend(loc=1)

# x-axis labels
ax.set_ylabel('Important y-axis info', fontsize=16)

# y-axis labels
ax.set_xlabel('Meaningless x-axis info', fontsize=16)

# %% [markdown]
# ### Horizontal bar plot

# %%
df.plot(kind='barh', figsize=(10,7))

# %% [markdown]
# ### Create a bar chart using col1 and col2.
# - Give it a large title of your choosing.
# - Move the legend to the lower-left corner.

# %%
ax = df[['col1','col2']].plot(kind='bar', figsize=(16,8))
ax.set_title('Something Important', fontsize=22)
ax.legend(loc=3)

# %% [markdown]
# - Do the same thing but with horizontal bars.
# - Move the legend to the upper right.

# %%
ax = df[['col1','col2']].plot(kind='barh', figsize=(16,8))
ax.set_title('Something Important', fontsize=22)
ax.legend(loc=1)

# %% [markdown]
# ### We can use stacked bars

# %%
df[['col2', 'col1']].plot(kind='bar', stacked=True, figsize=(15,7))

# %% [markdown]
# ### Stacked works on horizontal barcharts

# %%
df.plot(kind='barh', stacked=True, figsize=(16,8))

# %% [markdown]
# ### Plot the `.value_counts()` of `CHAS` using a bar chart

# %%
housing['CHAS'].value_counts().plot(kind='bar')

# %% [markdown]
# ### Create a vertical stacked bar chart using col1 and col2
# - What happens when you use `df[['col1', 'col2']]` vs. `df[['col2', 'col1']]`?

# %%
# solution
df[['col1', 'col2']].plot(kind='bar', stacked=True, figsize=(12,6))

# %% [markdown]
# ### Create a horizontal stacked bar chart using all columns from df

# %%
df.plot(kind='barh', stacked=True, figsize=(12,6))

# %% [markdown]
# ## Histograms
# ---

# %%
df.hist(figsize=(16,8));

# %% [markdown]
# ### Single historgram

# %%
norm = np.random.standard_normal(5000)

# %%
pd.Series(norm).hist(figsize=(16,4), bins=50)

# %% [markdown]
# ### Bins param adjusts the no. of bins

# %%
pd.Series(norm).hist(figsize=(16,4), bins=20)

# %% [markdown]
# ### Create a histogram with pandas for using `MEDV` in the housing data.
# - Set the bins to 20.

# %%
ax = housing['MEDV'].hist(bins=20)
ax.set_title('Distribution of Median Value of Housing');

# %% [markdown]
# ## Boxplots
# ---
#
# We can use boxplots to quickly summarize distributions

# %%
df.boxplot()
# Out:
# /Users/weekiang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x11970e310>,
#   <matplotlib.lines.Line2D at 0x119728b50>,
#   <matplotlib.lines.Line2D at 0x11942b790>,
#   <matplotlib.lines.Line2D at 0x1194183d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x11973d210>,
#   <matplotlib.lines.Line2D at 0x11973d850>,
#   <matplotlib.lines.Line2D at 0x11971ae10>,
#   <matplotlib.lines.Line2D at 0x119421ad0>,
#   <matplotlib.lines.Line2D at 0x119428a50>,
#   <matplotlib.lines.Line2D at 0x1194000d0>,
#   <matplotlib.lines.Line2D at 0x11949a690>,
#   <matplotlib.lines.Line2D at 0x11949acd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x119728510>,
#   <matplotlib.lines.Line2D at 0x11942b150>,
#   <matplotlib.lines.Line2D at 0x119400d50>,
#   <matplotlib.lines.Line2D at 0x1194b7990>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11973de90>,
#   <matplotlib.lines.Line2D at 0x119421850>,
#   <matplotlib.lines.Line2D at 0x119400710>,
#   <matplotlib.lines.Line2D at 0x1194b7350>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11970e4d0>,
#   <matplotlib.lines.Line2D at 0x11970eb90>,
#   <matplotlib.lines.Line2D at 0x11971a190>,
#   <matplotlib.lines.Line2D at 0x11971a7d0>,
#   <matplotlib.lines.Line2D at 0x11942bd90>,
#   <matplotlib.lines.Line2D at 0x119428410>,
#   <matplotlib.lines.Line2D at 0x1194189d0>,
#   <matplotlib.lines.Line2D at 0x11949a050>]}

# %% [markdown]
# ### Use a boxplot to preview the distributions in the housing data

# %%
housing.boxplot()
# Out:
# /Users/weekiang/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   if __name__ == '__main__':
# {'boxes': [<matplotlib.lines.Line2D at 0x11a336dd0>,
#   <matplotlib.lines.Line2D at 0x11a472650>,
#   <matplotlib.lines.Line2D at 0x11a495290>,
#   <matplotlib.lines.Line2D at 0x11a4aee90>,
#   <matplotlib.lines.Line2D at 0x11a4d0ad0>,
#   <matplotlib.lines.Line2D at 0x11a618710>,
#   <matplotlib.lines.Line2D at 0x1194e9110>,
#   <matplotlib.lines.Line2D at 0x11a648e90>,
#   <matplotlib.lines.Line2D at 0x11a66bc90>,
#   <matplotlib.lines.Line2D at 0x11a6908d0>,
#   <matplotlib.lines.Line2D at 0x11a6b3510>,
#   <matplotlib.lines.Line2D at 0x11a6d8150>,
#   <matplotlib.lines.Line2D at 0x11a6f2d50>,
#   <matplotlib.lines.Line2D at 0x11a714990>],
#  'caps': [<matplotlib.lines.Line2D at 0x11a348cd0>,
#   <matplotlib.lines.Line2D at 0x11a465350>,
#   <matplotlib.lines.Line2D at 0x11a47f910>,
#   <matplotlib.lines.Line2D at 0x11a47ff50>,
#   <matplotlib.lines.Line2D at 0x11a4a3550>,
#   <matplotlib.lines.Line2D at 0x11a4a3b90>,
#   <matplotlib.lines.Line2D at 0x11a4c6190>,
#   <matplotlib.lines.Line2D at 0x11a4c67d0>,
#   <matplotlib.lines.Line2D at 0x11a600d90>,
#   <matplotlib.lines.Line2D at 0x11a60b410>,
#   <matplotlib.lines.Line2D at 0x11a6219d0>,
#   <matplotlib.lines.Line2D at 0x11a62e050>,
#   <matplotlib.lines.Line2D at 0x11a63c710>,
#   <matplotlib.lines.Line2D at 0x11a63cd50>,
#   <matplotlib.lines.Line2D at 0x11a65f350>,
#   <matplotlib.lines.Line2D at 0x11a65f990>,
#   <matplotlib.lines.Line2D at 0x11a678f50>,
#   <matplotlib.lines.Line2D at 0x11a6855d0>,
#   <matplotlib.lines.Line2D at 0x11a69cb90>,
#   <matplotlib.lines.Line2D at 0x11a6a8210>,
#   <matplotlib.lines.Line2D at 0x11a6bf7d0>,
#   <matplotlib.lines.Line2D at 0x11a6bfe10>,
#   <matplotlib.lines.Line2D at 0x11a6e4410>,
#   <matplotlib.lines.Line2D at 0x11a6e4a50>,
#   <matplotlib.lines.Line2D at 0x11a708050>,
#   <matplotlib.lines.Line2D at 0x11a708690>,
#   <matplotlib.lines.Line2D at 0x11a721c50>,
#   <matplotlib.lines.Line2D at 0x11a72c2d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11a465fd0>,
#   <matplotlib.lines.Line2D at 0x11a489c10>,
#   <matplotlib.lines.Line2D at 0x11a4ae850>,
#   <matplotlib.lines.Line2D at 0x11a4d0490>,
#   <matplotlib.lines.Line2D at 0x11a6180d0>,
#   <matplotlib.lines.Line2D at 0x1194f5ed0>,
#   <matplotlib.lines.Line2D at 0x11a648a10>,
#   <matplotlib.lines.Line2D at 0x11a66b650>,
#   <matplotlib.lines.Line2D at 0x11a690290>,
#   <matplotlib.lines.Line2D at 0x11a6a8e90>,
#   <matplotlib.lines.Line2D at 0x11a6cbad0>,
#   <matplotlib.lines.Line2D at 0x11a6f2710>,
#   <matplotlib.lines.Line2D at 0x11a714350>,
#   <matplotlib.lines.Line2D at 0x11a72cf50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x11a465990>,
#   <matplotlib.lines.Line2D at 0x11a4895d0>,
#   <matplotlib.lines.Line2D at 0x11a4ae210>,
#   <matplotlib.lines.Line2D at 0x11a4c6e10>,
#   <matplotlib.lines.Line2D at 0x11a60ba50>,
#   <matplotlib.lines.Line2D at 0x1194c90d0>,
#   <matplotlib.lines.Line2D at 0x11a6483d0>,
#   <matplotlib.lines.Line2D at 0x11a65ffd0>,
#   <matplotlib.lines.Line2D at 0x11a685c10>,
#   <matplotlib.lines.Line2D at 0x11a6a8850>,
#   <matplotlib.lines.Line2D at 0x11a6cb490>,
#   <matplotlib.lines.Line2D at 0x11a6f20d0>,
#   <matplotlib.lines.Line2D at 0x11a708cd0>,
#   <matplotlib.lines.Line2D at 0x11a72c910>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x11a336f90>,
#   <matplotlib.lines.Line2D at 0x11a348690>,
#   <matplotlib.lines.Line2D at 0x11a472c50>,
#   <matplotlib.lines.Line2D at 0x11a47f2d0>,
#   <matplotlib.lines.Line2D at 0x11a495890>,
#   <matplotlib.lines.Line2D at 0x11a495ed0>,
#   <matplotlib.lines.Line2D at 0x11a4b94d0>,
#   <matplotlib.lines.Line2D at 0x11a4b9b10>,
#   <matplotlib.lines.Line2D at 0x11a600110>,
#   <matplotlib.lines.Line2D at 0x11a600750>,
#   <matplotlib.lines.Line2D at 0x11a618d10>,
#   <matplotlib.lines.Line2D at 0x11a621390>,
#   <matplotlib.lines.Line2D at 0x11a62ea50>,
#   <matplotlib.lines.Line2D at 0x11a63c0d0>,
#   <matplotlib.lines.Line2D at 0x11a654690>,
#   <matplotlib.lines.Line2D at 0x11a654cd0>,
#   <matplotlib.lines.Line2D at 0x11a6782d0>,
#   <matplotlib.lines.Line2D at 0x11a678910>,
#   <matplotlib.lines.Line2D at 0x11a690ed0>,
#   <matplotlib.lines.Line2D at 0x11a69c550>,
#   <matplotlib.lines.Line2D at 0x11a6b3b10>,
#   <matplotlib.lines.Line2D at 0x11a6bf190>,
#   <matplotlib.lines.Line2D at 0x11a6d8750>,
#   <matplotlib.lines.Line2D at 0x11a6d8d90>,
#   <matplotlib.lines.Line2D at 0x11a6fc390>,
#   <matplotlib.lines.Line2D at 0x11a6fc9d0>,
#   <matplotlib.lines.Line2D at 0x11a714f90>,
#   <matplotlib.lines.Line2D at 0x11a721610>]}

# %% [markdown]
# ## Scatter Plots
# ---

# %%
df.plot(x='col3', y='col4', kind='scatter', color='dodgerblue',\
        figsize=(15,7), s=550)

# %% [markdown]
# ### View the association between the variables `"ZN"` and `"INDUS"` using a scatter plot.

# %%
housing.plot(x='ZN', y='INDUS', kind='scatter', 
           color='dodgerblue', figsize=(15,7), s=100)

# %% [markdown]
# ### Use a list comprehension to change the size of the scatter plot dots based on `DIS`

# %%
housing.plot(x='ZN', y='INDUS', kind='scatter', 
           color='dodgerblue', figsize=(15,7), s=[x**2 for x in housing['DIS']])

# %% [markdown]
# ## Seaborn `pairplot`
#
# ---
#
# With the dataframe object `housing`, we will render a pairplot using the Seaborn library.
# What do each of the elements represent? Is this more or less useful than the previous plot?

# %%
sns.pairplot(housing)

# %% [markdown]
# **Answer:** _What do each of the elements represent?  Is this more or less useful than the previous plot?_
# > In a pair plot we get to see every relationship between every _pair_ of variables.  We can see this is very useful for quickly discovering which variables have some kind of correlation during an exploratory data analysis.  However, when just looking at the `INDUS` feature, the pair plot is more difficult to read and interpret as opposed to the single histogram.

# %% [markdown]
# ## Seaborn `heatmap`
# ---
#
# When you have too many variables, a pairplot or scatter matrix can become impossible to read. We can still gauge linear correlation using a heatmap of the correlation matrix.

# %%
# make a heatmap on the correlations between variables in the housing data:
housing_correlations = housing.corr()
sns.heatmap(housing_correlations)

# %% [markdown]
# ## Understanding figures, subplots, and axes
#
# ---

# %% [markdown]
# Matplotlib uses a blank canvas called a figure

# %%
fig = plt.subplots(1,1, figsize=(16,8))

# %% [markdown]
# Within this canvas, we can contain smaller objects called axes

# %%
fig, axes = plt.subplots(2,3, figsize=(16,8))

# %% [markdown]
# Pandas allows us to plot to a specified axes if we pass the object to the ax paramter.

# %%
fig, axes = plt.subplots(2,3, figsize=(16,8))
df.plot(ax=axes[0][0])
df['col1'].plot(ax=axes[0][1])
df['col2'].plot(ax=axes[1][1])

# %% [markdown]
# ## Let's use a bit more customization
# ---

# %%
fig, axes = plt.subplots(2,2, figsize=(16,8))

# We can change the ticks' size
df['col2'].plot(figsize=(16,4), color='purple', fontsize=21, ax=axes[0][0])

# We can also change which ticks are visible
# list comprehension to get only the even ticks
ticks_to_show = [idx for idx, _ in enumerate(df['col2'].index) if idx % 2 == 0]
df['col2'].plot(figsize=(16,4), color='purple', xticks=ticks_to_show, fontsize=16, ax=axes[0][1])

# We can change the label rotation
df.plot(figsize=(15,7), title='Big Rotated Labels - Tiny Title',\
        fontsize=20, rot=-50, ax=axes[1][0])\

# We have to use .set_title() to fix title size
df.plot(figsize=(16,8), fontsize=20, rot=-50, ax=axes[1][1])\
       .set_title('Better-Sized Title', fontsize=21, y=1.01)
